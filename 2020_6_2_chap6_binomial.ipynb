# %% [markdown]
# <a href="https://colab.research.google.com/github/xiaoyi-yuxiao/python-code-for-FinancialAnalysis-book/blob/master/2020_6_2_chap6_binomial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Jun-11-2020
import numpy as np
import pandas as pd
import operator as op
from functools import reduce
import matplotlib.pyplot as plt

# %%
##define the function of n choose k
def ncr(n, r):
    r = min(r, n-r)
    numer = reduce(op.mul, range(n, n-r, -1), 1)
    denom = reduce(op.mul, range(1, r+1), 1)
    return numer / denom
##define the calculation

def calculate_pdf (n, k, p):
    return ncr(n, k)*pow(p,k)*pow((1-p),n-k)

# %%
probability = np.zeros((31,3))##set the dataframe for probability
p = [0.25,0.5,0.75]
for i in range(3):
    for j in range(31):
        probability[j,i] = calculate_pdf(30,j,p[i])

prob = pd.DataFrame(probability)
prob.columns = ['25 percent', '50 percent','75 percent']

#compute culmulated probability density
cdf = prob.cumsum()

#plot cdf
fig2, bx = plt.subplots()
bx.plot(cdf['25 percent'],'g--', label='25 percent')
bx.plot(cdf['50 percent'],'r:', label='75 percent')
bx.plot(cdf['75 percent'],'b', label='75 percent')

legend = bx.legend(loc=0, shadow=True)
plt.xlabel('success')
plt.ylabel('probability')
# Out:
# Text(0, 0.5, 'probability')

# %%
plt.plot(prob['50 percent'])

plt.xlabel('success')
plt.ylabel('probability')
plt.title('Binomial Probability Density Function')
plt.legend(['50 percent'])

# %%
plt.plot(cdf['50 percent'])

plt.xlabel('success')
plt.ylabel('probability')
plt.title('Binomial Probability Density Function')
plt.legend(['50 percent'])

# %%
pd.options.display.float_format = '{:,.6f}'.format
print('     50 percent')
print(prob['50 percent'])
# Out:
# .     50 percent
# 0    0.000000
# 1    0.000000
# 2    0.000000
# 3    0.000004
# 4    0.000026
# 5    0.000133
# 6    0.000553
# 7    0.001896
# 8    0.005451
# 9    0.013325
# 10   0.027982
# 11   0.050876
# 12   0.080553
# 13   0.111535
# 14   0.135435
# 15   0.144464
# 16   0.135435
# 17   0.111535
# 18   0.080553
# 19   0.050876
# 20   0.027982
# 21   0.013325
# 22   0.005451
# 23   0.001896
# 24   0.000553
# 25   0.000133
# 26   0.000026
# 27   0.000004
# 28   0.000000
# 29   0.000000
# 30   0.000000
# Name: 50 percent, dtype: float64

# %%
print('     50 percent')
print(cdf['50 percent'])
# Out:
# .     50 percent
# 0    0.000000
# 1    0.000000
# 2    0.000000
# 3    0.000004
# 4    0.000030
# 5    0.000162
# 6    0.000715
# 7    0.002611
# 8    0.008062
# 9    0.021387
# 10   0.049369
# 11   0.100244
# 12   0.180797
# 13   0.292332
# 14   0.427768
# 15   0.572232
# 16   0.707668
# 17   0.819203
# 18   0.899756
# 19   0.950631
# 20   0.978613
# 21   0.991938
# 22   0.997389
# 23   0.999285
# 24   0.999838
# 25   0.999970
# 26   0.999996
# 27   1.000000
# 28   1.000000
# 29   1.000000
# 30   1.000000
# Name: 50 percent, dtype: float64

# %%
fig, ax = plt.subplots()
ax.plot(prob['25 percent'],'g--', label='25 percent')
ax.plot(prob['50 percent'],'r:', label='75 percent')
ax.plot(prob['75 percent'],'b', label='75 percent')

legend = ax.legend(loc='upper right', shadow=True)
plt.xlabel('success')
plt.ylabel('probability')
plt.title('Binomial Probability Density Function')
# Out:
# Text(0.5, 1.0, 'Binomial Probability Density Function')

# %%
print(prob)
# Out:
#     25 percent  50 percent  75 percent
# 0     0.000179    0.000000    0.000000
# 1     0.001786    0.000000    0.000000
# 2     0.008631    0.000000    0.000000
# 3     0.026853    0.000004    0.000000
# 4     0.060420    0.000026    0.000000
# 5     0.104728    0.000133    0.000000
# 6     0.145456    0.000553    0.000000
# 7     0.166236    0.001896    0.000000
# 8     0.159309    0.005451    0.000000
# 9     0.129807    0.013325    0.000000
# 10    0.090865    0.027982    0.000002
# 11    0.055070    0.050876    0.000008
# 12    0.029065    0.080553    0.000040
# 13    0.013414    0.111535    0.000166
# 14    0.005430    0.135435    0.000603
# 15    0.001931    0.144464    0.001931
# 16    0.000603    0.135435    0.005430
# 17    0.000166    0.111535    0.013414
# 18    0.000040    0.080553    0.029065
# 19    0.000008    0.050876    0.055070
# 20    0.000002    0.027982    0.090865
# 21    0.000000    0.013325    0.129807
# 22    0.000000    0.005451    0.159309
# ...

# %%
print(cdf)
# Out:
#     25 percent  50 percent  75 percent
# 0     0.000179    0.000000    0.000000
# 1     0.001964    0.000000    0.000000
# 2     0.010596    0.000000    0.000000
# 3     0.037449    0.000004    0.000000
# 4     0.097870    0.000030    0.000000
# 5     0.202598    0.000162    0.000000
# 6     0.348054    0.000715    0.000000
# 7     0.514290    0.002611    0.000000
# 8     0.673599    0.008062    0.000000
# 9     0.803407    0.021387    0.000000
# 10    0.894272    0.049369    0.000002
# 11    0.949342    0.100244    0.000010
# 12    0.978406    0.180797    0.000050
# 13    0.991821    0.292332    0.000216
# 14    0.997250    0.427768    0.000819
# 15    0.999181    0.572232    0.002750
# 16    0.999784    0.707668    0.008179
# 17    0.999950    0.819203    0.021594
# 18    0.999990    0.899756    0.050658
# 19    0.999998    0.950631    0.105728
# 20    1.000000    0.978613    0.196593
# 21    1.000000    0.991938    0.326401
# 22    1.000000    0.997389    0.485710
# ...

# %%
fig2, bx = plt.subplots()
bx.plot(cdf['25 percent'],'g--', label='25 percent')
bx.plot(cdf['50 percent'],'r:', label='75 percent')
bx.plot(cdf['75 percent'],'b', label='75 percent')

legend = bx.legend(loc=0, shadow=True)
plt.xlabel('success')
plt.ylabel('probability')
plt.title('Binomial Cumulative Dendity Function')
# Out:
# Text(0.5, 1.0, 'Binomial Cumulative Dendity Function')
